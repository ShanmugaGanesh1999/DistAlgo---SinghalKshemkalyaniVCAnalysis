# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
maximumLenghtMessageConstruction = [0, 0, 0, 0, 0, 4, 6, 6, 6, 6, 8, 9, 10, 9, 9, 10, 14, 15, 15, 9, 11, 15, 12, 21, 14, 17, 14, 15, 17, 16, 20, 21, 22, 19, 21, 20, 22, 16, 15, 24, 17, 30, 21, 24, 25, 26, 27, 30, 28, 19, 27, 22, 17, 24, 24, 33, 25, 21, 20, 25, 23, 35, 31, 23, 26, 26, 40, 38, 28, 29, 30, 31, 32, 37, 36, 42, 24, 27, 33, 32, 43, 35, 37, 29, 25, 39, 43, 40, 36, 31, 48, 38, 37, 34, 38, 31, 33, 31, 35, 41]
averageLengthMessageConstruction = [0, 0, 0, 0, 0, 8, 12, 12, 11, 12, 11, 13, 13, 12, 14, 15, 21, 21, 15, 12, 14, 21, 15, 21, 19, 19, 19, 19, 23, 18, 22, 21, 21, 20, 24, 24, 23, 16, 18, 23, 22, 22, 21, 20, 23, 21, 19, 24, 23, 23, 24, 26, 21, 26, 23, 22, 23, 19, 24, 23, 23, 26, 26, 21, 27, 27, 26, 31, 22, 25, 24, 27, 23, 25, 28, 29, 24, 26, 26, 30, 28, 28, 26, 25, 24, 25, 30, 28, 29, 26, 32, 24, 31, 24, 29, 26, 28, 28, 26, 25]
maximumNumberMessageUpdation = [0, 0, 0, 0, 0, 3, 5, 5, 5, 5, 4, 6, 9, 9, 8, 10, 12, 11, 9, 8, 9, 13, 9, 18, 12, 16, 13, 13, 12, 12, 15, 17, 16, 18, 19, 16, 21, 12, 12, 21, 16, 25, 17, 20, 25, 25, 21, 26, 24, 18, 17, 20, 15, 22, 23, 30, 18, 17, 20, 20, 23, 30, 29, 23, 22, 24, 35, 27, 23, 29, 28, 28, 26, 28, 34, 28, 19, 26, 28, 32, 41, 26, 31, 23, 20, 28, 40, 39, 33, 29, 34, 37, 36, 25, 37, 30, 29, 27, 33, 32]
averageNumberMessageUpdation = [0, 0, 0, 0, 0, 6, 9, 9, 8, 9, 8, 9, 10, 9, 10, 11, 15, 14, 12, 9, 12, 15, 12, 15, 14, 14, 15, 15, 16, 14, 16, 16, 16, 16, 18, 18, 17, 13, 14, 17, 17, 17, 16, 17, 18, 17, 15, 19, 18, 18, 19, 20, 17, 20, 19, 18, 19, 16, 19, 19, 18, 21, 21, 18, 22, 21, 21, 24, 18, 21, 19, 21, 18, 20, 24, 23, 19, 22, 21, 24, 23, 23, 22, 21, 20, 20, 25, 23, 24, 21, 25, 20, 26, 20, 24, 22, 24, 22, 23, 21]

# %%
x = range(len(maximumLenghtMessageConstruction))

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))

ax1.plot(x, maximumLenghtMessageConstruction, label="construction (send event)", linestyle='dashdot')
ax1.plot(x, maximumNumberMessageUpdation, label="updation (receive event)", linestyle='--')
ax1.set_xlabel('No of process')
ax1.set_ylabel('maximum length of message')
ax1.set_title('maximum no of message _')
ax1.legend()

ax2.plot(x, averageLengthMessageConstruction, label="construction (send event)", linestyle='dashdot')
ax2.plot(x, averageNumberMessageUpdation, label="updation (receive event)", linestyle="--")
ax2.set_xlabel('No of process')
ax2.set_ylabel('average length of message')
ax2.set_title('average no of message _')
ax2.legend()

plt.tight_layout()
plt.show()

# %%
def calculate_percentage(x, y):
    return np.array(x)/ np.array(y)

# %%
diff_max = calculate_percentage(maximumLenghtMessageConstruction[5:], maximumNumberMessageUpdation[5:])

np.max(diff_max), np.average(diff_max)
# Out:
# (2.0, 1.189907402328239)

# %%
diff_avg = calculate_percentage(averageLengthMessageConstruction[5:], averageNumberMessageUpdation[5:])

np.average(diff_avg)
# Out:
# 1.2712650847175826

# %% [markdown]
# ## Message Construction = 1.27 * Message Updation
